# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
data =pd.read_csv("heart_attack_russia.csv")
data
# Out:
#           ID  Age  Gender    Region  Blood_Pressure  Cholesterol   BMI  \
# 0          1   50    Male     Rural           110.0        196.5  15.9
# 1          2   40  Female     Urban           138.8        157.5  27.1
# 2          3   26    Male     Rural           116.0        210.1  27.2
# 3          4   54  Female     Rural           133.5        170.5  26.0
# 4          5   19  Female     Urban           108.0        224.5  27.5
# ...      ...  ...     ...       ...             ...          ...   ...
# 49995  49996   56   Other     Rural            87.7        256.8  25.3
# 49996  49997   16    Male     Rural           125.2        102.9  25.1
# 49997  49998   46  Female  Suburban           116.2        160.6  27.7
# 49998  49999   24  Female     Rural           104.6        180.4  29.2
# 49999  50000   38    Male     Urban           122.9         89.2  21.8
#
#        Heart_Rate Exercise_Level  Smoking  ... Income_Level  \
# ...

# %%
data.isnull().sum()
df=data.dropna()
df
df.isnull().sum()
# Out:
# ID                       0
# Age                      0
# Gender                   0
# Region                   0
# Blood_Pressure           0
# Cholesterol              0
# BMI                      0
# Heart_Rate               0
# Exercise_Level           0
# Smoking                  0
# Alcohol_Consumption      0
# Diabetes                 0
# Family_History           0
# Stress_Level             0
# Heart_Attack             0
# Angina                   0
# Heart_Disease_History    0
# Diet                     0
# Sleep_Hours              0
# Occupation               0
# Income_Level             0
# Physical_Activity        0
# Education_Level          0
# Marital_Status           0
# Urban_Rural              0
# Medication               0
# Health_Awareness         0
# Daily_Water_Intake       0
# Mental_Health            0
# Obesity                  0
# dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Region', 'Blood_Pressure', 'Cholesterol', 'BMI',
#        'Heart_Rate', 'Exercise_Level', 'Smoking', 'Alcohol_Consumption',
#        'Diabetes', 'Family_History', 'Stress_Level', 'Heart_Attack', 'Angina',
#        'Heart_Disease_History', 'Diet', 'Sleep_Hours', 'Occupation',
#        'Income_Level', 'Physical_Activity', 'Education_Level',
#        'Marital_Status', 'Urban_Rural', 'Medication', 'Health_Awareness',
#        'Daily_Water_Intake', 'Mental_Health', 'Obesity'],
#       dtype='object')

# %%
df["Heart_Attack"]
from sklearn.preprocessing import LabelEncoder
encoder =LabelEncoder()
df["Attack"]=encoder.fit_transform(df["Heart_Attack"])
df["Attack"]
df=df.drop("Heart_Attack",axis=1)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_15820\1580859704.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Attack"]=encoder.fit_transform(df["Heart_Attack"])

# %%
x =df.drop(columns=["Attack"],)
y =df["Attack"]

# %%
y
# Out:
# 0        0
# 2        0
# 3        0
# 6        1
# 8        1
#         ..
# 49994    0
# 49995    0
# 49997    0
# 49998    1
# 49999    0
# Name: Attack, Length: 24976, dtype: int64

# %%
x.describe
# Out:
# <bound method NDFrame.describe of           ID  Age  Gender    Region  Blood_Pressure  Cholesterol   BMI  \
# 0          1   50    Male     Rural           110.0        196.5  15.9
# 2          3   26    Male     Rural           116.0        210.1  27.2
# 3          4   54  Female     Rural           133.5        170.5  26.0
# 6          7   50    Male  Suburban           116.8        206.9  27.9
# 8          9   34    Male     Urban           131.8        244.6  24.4
# ...      ...  ...     ...       ...             ...          ...   ...
# 49994  49995   37    Male     Rural           137.2        163.2  22.2
# 49995  49996   56   Other     Rural            87.7        256.8  25.3
# 49997  49998   46  Female  Suburban           116.2        160.6  27.7
# 49998  49999   24  Female     Rural           104.6        180.4  29.2
# 49999  50000   38    Male     Urban           122.9         89.2  21.8
#
#        Heart_Rate Exercise_Level  Smoking  ... Income_Level  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# List of categorical columns to encode
categorical_columns = ['Gender', 'Region', 'Exercise_Level', 'Smoking', 'Income_Level', 
                       'Physical_Activity', 'Education_Level', 'Marital_Status', 
                       'Urban_Rural', 'Medication', 'Health_Awareness', 'Mental_Health', 'Obesity']

# Apply label encoding to each categorical column
for col in categorical_columns:
    df[col] = label_encoder.fit_transform(df[col])

# Check the transformed DataFrame
print(df.head())
# Out:
#    ID  Age  Gender  Region  Blood_Pressure  Cholesterol   BMI  Heart_Rate  \
# 0   1   50       1       0           110.0        196.5  15.9          76
# 2   3   26       1       0           116.0        210.1  27.2          71
# 3   4   54       0       0           133.5        170.5  26.0          74
# 6   7   50       1       1           116.8        206.9  27.9          75
# 8   9   34       1       2           131.8        244.6  24.4          65
#
#    Exercise_Level  Smoking  ... Physical_Activity  Education_Level  \
# 0               0        0  ...                 1                1
# 2               2        0  ...                 0                1
# 3               2        1  ...                 2                0
# 6               0        1  ...                 2                1
# 8               1        0  ...                 2                1
#
#    Marital_Status  Urban_Rural  Medication  Health_Awareness  \
# ...
